# %% [markdown]
# <a href="https://colab.research.google.com/github/sreesathiya175/codsoftai/blob/main/Copy_of_Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mtcnn
# !pip install keras
# !pip install tensorflow

from mtcnn.mtcnn import MTCNN
from PIL import Image
import matplotlib.pyplot as plt


image = plt.imread('grppp.jpg')

detector = MTCNN()
faces = detector.detect_faces(image)

print('Number of faces detected:',len(faces))

for face in faces:
  x, y, width, height = face['box']
  plt.plot([x, x + width, x + width, x, x], [y, y, y + height,y + height, y], 'r')
  plt.imshow(image)
  plt.show()
# Out:
# ...
# 4/4 [==============================] - 0s 28ms/step
# Number of faces detected: 14
